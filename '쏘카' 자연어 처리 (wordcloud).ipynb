# %%
import pandas as pd

a = pd.read_csv("C:/Users/katenam/Socar_Review.csv")
b = pd.read_csv("C:/Users/katenam/Socar_Review_2.csv")
a
# Out:
#                                               Comments
# 0    저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1               하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2            차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3    이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4    저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...
# ..                                                 ...
# 304   막상 지내다보면\n밖에 외출할일이 생기자나요\n맘편하게 렌트가 이로울수 있을거 같습니다
# 305                               쏘카도 요즘에 차 거의 없더라구요ㅠㅠ
# 306                                                 ㅠㅠ
# 307       저두 써봤는데 쏘카존까지 안가도 되고, 무엇보다도 무료라는게 넘 좋아요 ㅋㅋㅋㅋ
# 308                               맞아요 ㅠ 자주 이용하는데 넘 좋네요
#
# [309 rows x 1 columns]

# %%
b
# Out:
#                                               Comments
# 0                                        와이프 그렇게 연수시킴여
# 1                       쏘카로 하지마시고 가족차로 하세요 누굴 피해줄려고...
# 2                             연수 시켜줄사람있으면 ㄱㅊ 혼자할거면 ㄴㄴ여
# 3      렌트로 운전연습 하지마세요..\n\n차라리 윤전학원가서 도로연수 돈내고 받으시길..ㅡ
# 4                                  남의 차로요? 사고나면 골치아플텐데
# ..                                                 ...
# 586  김포ll어슬Cruise control 의 한단계 진화된 기술을 ACC 혹은 SCC ...
# 587              서울ll김동현그럼캐스퍼는 크루즈인거죠? 스마트가 훨씬좋은거네요~~~
# 588  김포ll어슬캐스퍼는 일반적으로 깡통을 사면 기본 크루즈만 들어가요 속도 고정으로 달...
# 589  서울ll김동현인스는 스마트에요? 몰랐네요 ㅋㅋㅋ 그럼 제차도 되는거네요? 근데 무서...
# 590  김포ll어슬당연하죵 ㅎㅎ\n캐스퍼에 장착된 SCC는 완전정차 및 정차후 재출발 기능...
#
# [591 rows x 1 columns]

# %%
review = pd.concat([a,b]) # 2개의 csv 파일을 하나로 병합 concat 사용
review
# Out:
#                                               Comments
# 0    저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1               하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2            차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3    이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4    저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...
# ..                                                 ...
# 586  김포ll어슬Cruise control 의 한단계 진화된 기술을 ACC 혹은 SCC ...
# 587              서울ll김동현그럼캐스퍼는 크루즈인거죠? 스마트가 훨씬좋은거네요~~~
# 588  김포ll어슬캐스퍼는 일반적으로 깡통을 사면 기본 크루즈만 들어가요 속도 고정으로 달...
# 589  서울ll김동현인스는 스마트에요? 몰랐네요 ㅋㅋㅋ 그럼 제차도 되는거네요? 근데 무서...
# 590  김포ll어슬당연하죵 ㅎㅎ\n캐스퍼에 장착된 SCC는 완전정차 및 정차후 재출발 기능...
#
# [900 rows x 1 columns]

# %%
review.to_csv("C:/Users/katenam/Socar_Review_final.csv", index=False)

# %%
review = pd.read_csv("C:/Users/katenam/Socar_Review_final.csv")
review.head()
# Out:
#                                             Comments
# 0  저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1             하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2          차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3  이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4  저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Comments  869 non-null    object
# dtypes: object(1)
# memory usage: 7.2+ KB

# %%
review.isnull().sum()
# Out:
# Comments    31
# dtype: int64

# %%
review[review['Comments'].isnull()]
# Out:
#     Comments
# 43       NaN
# 48       NaN
# 122      NaN
# 123      NaN
# 140      NaN
# 178      NaN
# 180      NaN
# 182      NaN
# 185      NaN
# 186      NaN
# 239      NaN
# 240      NaN
# 258      NaN
# 259      NaN
# 280      NaN
# 332      NaN
# 333      NaN
# 527      NaN
# 528      NaN
# 531      NaN
# 538      NaN
# 539      NaN
# 705      NaN
# 706      NaN
# 779      NaN
# 786      NaN
# 846      NaN
# 848      NaN
# 850      NaN
# 885      NaN
# 886      NaN

# %%
review_1 = review.dropna() # 결측치 삭제
review_1
# Out:
#                                               Comments
# 0    저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1               하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2            차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3    이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4    저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...
# ..                                                 ...
# 586  김포ll어슬Cruise control 의 한단계 진화된 기술을 ACC 혹은 SCC ...
# 587              서울ll김동현그럼캐스퍼는 크루즈인거죠? 스마트가 훨씬좋은거네요~~~
# 588  김포ll어슬캐스퍼는 일반적으로 깡통을 사면 기본 크루즈만 들어가요 속도 고정으로 달...
# 589  서울ll김동현인스는 스마트에요? 몰랐네요 ㅋㅋㅋ 그럼 제차도 되는거네요? 근데 무서...
# 590  김포ll어슬당연하죵 ㅎㅎ\n캐스퍼에 장착된 SCC는 완전정차 및 정차후 재출발 기능...
#
# [869 rows x 1 columns]

# %%
review_1.isnull().sum()
# Out:
# Comments    0
# dtype: int64

# %%
review_2 = review_1.drop_duplicates() # 같은 열 제거(내용이 같은 열이 몇개 있었음)
review_2
# Out:
#                                               Comments
# 0    저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1               하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2            차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3    이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4    저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...
# ..                                                 ...
# 586  김포ll어슬Cruise control 의 한단계 진화된 기술을 ACC 혹은 SCC ...
# 587              서울ll김동현그럼캐스퍼는 크루즈인거죠? 스마트가 훨씬좋은거네요~~~
# 588  김포ll어슬캐스퍼는 일반적으로 깡통을 사면 기본 크루즈만 들어가요 속도 고정으로 달...
# 589  서울ll김동현인스는 스마트에요? 몰랐네요 ㅋㅋㅋ 그럼 제차도 되는거네요? 근데 무서...
# 590  김포ll어슬당연하죵 ㅎㅎ\n캐스퍼에 장착된 SCC는 완전정차 및 정차후 재출발 기능...
#
# [759 rows x 1 columns]

# %%
review_total=[]

for i in review_2['Comments']:
    review_total.append(i)

review_total
# Out:
# ['저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에 있는 카드로 하면 돼용',
#  '하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??',
#  '차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요',
#  '이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 받구요~\n요즘 렌트비 얼마받는지 모르겠네요~\n쏘카존이 가까이 있고 대여료 보험료 포함6만원 미만이면 주행후 8만원 또는 그 나온다 생각하심 계산 나올거에요',
#  '저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것 이용하면 괜찮더라고요. 무엇보다 무인 시스템이라 편한거 같아요. 즐거운 여행되세용:-)',
#  '제가할께요',
#  '쏘카 까시면 걍 나와여 그린카 쏘카 다 비슷하구여\n시간+거리로 하는거라 모르는거에여 막히면 시간이 엄청 느는거니까여\n일반 렌터카랑 아주 큰 차이는 안나요',
#  '감사합니당',
#  '그게 더 비쌀수도 있을 것 같아요,, 쏘카는 주행거리로도 가격 계산하니까 ! 서울에서 강릉까지 케텍스 타고 거기서 쏘카 하는게 젤 나을거같아요',
#  '렌터카인데 시간단위로 빌리는 거죠',
#  '오홍! 감사합니당 ㅎㅎㅎㅎ 아예 개념이 안잡혔엇거든요',
#  '같은 렌터이지만 시간단위에다가 바가지 덮어버리는 악체사장님들 많아여',
#  '쏘카요????',
#  '알랍비어넵 쏘카여',
#  '노름즐기는흰둥이헉 바가지 덮어씌울수가있나요? 어플인데 ㅠㅠ!!!! 불안하네요',
#  '편도로 빌려서, 지정된 다른 지역에 반납은 가능한데 비싸요',
#  '오오 숙소는 예약하셧나요ㅠㅠ 저는 완전 라스트 미닛…',
#  '마리안느 정Zzzㅋㅋㅋㅋㅋㅋㅋ저인줄..파워 P입니다 ㅋㅋㅋㅋㅋㅋㅋ🤗 ㅠㅠ 숙소가 마땅치 않더라구요 ㅋㅋㅋㅋ 고민고민 ㅋㅋㅋㅋ 빨리 결단을 내려야되는데ㅠㅠ 언제 가시나요',
#  '두개 비교해보시고 싼걸로 가심될듯',
# ...

# %%
result = ' '.join(s for s in review_total) # review_total 리스트를 문자열로 형태소 분석을 하기 위해 문자열로 바꾸기
print(result)
# Out:
# 저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에 있는 카드로 하면 돼용 하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요?? 차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요 이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 받구요~
# 요즘 렌트비 얼마받는지 모르겠네요~
# 쏘카존이 가까이 있고 대여료 보험료 포함6만원 미만이면 주행후 8만원 또는 그 나온다 생각하심 계산 나올거에요 저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것 이용하면 괜찮더라고요. 무엇보다 무인 시스템이라 편한거 같아요. 즐거운 여행되세용:-) 제가할께요 쏘카 까시면 걍 나와여 그린카 쏘카 다 비슷하구여
# 시간+거리로 하는거라 모르는거에여 막히면 시간이 엄청 느는거니까여
# 일반 렌터카랑 아주 큰 차이는 안나요 감사합니당 그게 더 비쌀수도 있을 것 같아요,, 쏘카는 주행거리로도 가격 계산하니까 ! 서울에서 강릉까지 케텍스 타고 거기서 쏘카 하는게 젤 나을거같아요 렌터카인데 시간단위로 빌리는 거죠 오홍! 감사합니당 ㅎㅎㅎㅎ 아예 개념이 안잡혔엇거든요 같은 렌터이지만 시간단위에다가 바가지 덮어버리는 악체사장님들 많아여 쏘카요???? 알랍비어넵 쏘카여 노름즐기는흰둥이헉 바가지 덮어씌울수가있나요? 어플인데 ㅠㅠ!!!! 불안하네요 편도로 빌려서, 지정된 다른 지역에 반납은 가능한데 비싸요 오오 숙소는 예약하셧나요ㅠㅠ 저는 완전 라스트 미닛… 마리안느 정Zzzㅋㅋㅋㅋㅋㅋㅋ저인줄..파워 P입니다 ㅋㅋㅋㅋㅋㅋㅋ🤗 ㅠㅠ 숙소가 마땅치 않더라구요 ㅋㅋㅋㅋ 고민고민 ㅋㅋㅋㅋ 빨리 결단을 내려야되는데ㅠㅠ 언제 가시나요 두개 비교해보시고 싼걸로 가심될듯 1~2만원 차이인거같은데 렌트하기 편한걸로 하세요 자차가났지않을까요? 혹시라도사고나면... 장거리면 쏘카 전기차 이용해보세요 전기료 행사도 하던데요 렌트카 사고 나면 집 팔아야되니..
# ...

# %%
# Okt 이용

# %%
from collections import Counter
review_counts = Counter(result)

# %%
review_counts.most_common(50)
# Out:
# [(' ', 6982),
#  ('요', 826),
#  ('.', 723),
#  ('이', 676),
#  ('는', 543),
#  ('다', 543),
#  ('고', 439),
#  ('가', 438),
#  ('하', 426),
#  ('니', 386),
#  ('도', 340),
#  ('서', 338),
#  ('어', 319),
#  ('카', 315),
#  ('에', 315),
#  ('시', 310),
#  ('아', 287),
#  ('\n', 285),
#  ('ㅋ', 283),
#  ('보', 264),
#  ('차', 263),
#  ('지', 263),
#  ('로', 253),
#  ('그', 250),
#  ('해', 249),
#  ('!', 246),
#  ('은', 234),
#  ('데', 226),
#  ('사', 225),
#  ('거', 222),
#  ('면', 222),
#  ('라', 217),
#  ('ㅎ', 212),
#  ('리', 211),
#  ('기', 209),
#  ('나', 208),
#  ('네', 192),
#  ('쏘', 189),
#  ('~', 188),
#  ('l', 178),
#  ('ㅠ', 176),
#  ('주', 162),
#  ('있', 161),
#  ('용', 156),
#  ('구', 156),
#  ('전', 155),
#  ('만', 152),
#  ('인', 142),
#  ('정', 139),
#  ('?', 139)]

# %%
from konlpy.tag import Okt


okt = Okt()
nouns = okt.nouns(result) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
c
# Out:
# Counter({'자주': 8,
#          '이용': 59,
#          '거리': 23,
#          '계산': 5,
#          '주유': 11,
#          '카드': 8,
#          '하루': 7,
#          '종일': 1,
#          '드라이브': 2,
#          '코스': 1,
#          '혹시': 13,
#          '가격': 23,
#          '정도': 24,
#          '차종': 4,
#          '기본': 7,
#          '세팅': 1,
#          '이건': 6,
#          '요금': 26,
#          '쿠폰': 20,
#          '퍼센트': 1,
#          '이상': 6,
#          '할인': 11,
#          '요즘': 14,
#          '렌트': 34,
#          '얼마': 9,
#          '카존': 6,
#          '가까이': 4,
#          '대여': 6,
#          '보험료': 5,
#          '포함': 3,
#          '미만': 2,
#          '이면': 3,
#          '주행': 27,
#          '생각': 34,
#          '여수': 1,
#          '비용': 13,
#          '무엇': 2,
#          '무인': 1,
#          '시스템': 4,
#          '여행': 4,
#          '그린': 52,
#          '시간': 30,
#          '일반': 7,
#          '렌터카': 7,
#          '아주': 3,
#          '안나': 3,
#          '그게': 8,
#          '서울': 25,
# ...

# %%
c.most_common(50)
# Out:
# [('이용', 59),
#  ('그린', 52),
#  ('운전', 49),
#  ('차량', 36),
#  ('경기', 36),
#  ('렌트', 34),
#  ('생각', 34),
#  ('터보', 34),
#  ('시간', 30),
#  ('보험', 30),
#  ('주행', 27),
#  ('요금', 26),
#  ('서울', 25),
#  ('사용', 25),
#  ('정도', 24),
#  ('거리', 23),
#  ('가격', 23),
#  ('사고', 23),
#  ('렌트카', 22),
#  ('그냥', 21),
#  ('정보', 21),
#  ('진짜', 21),
#  ('문제', 21),
#  ('옵션', 21),
#  ('타이어', 21),
#  ('쿠폰', 20),
#  ('운행', 20),
#  ('일산', 20),
#  ('한번', 19),
#  ('차로', 19),
#  ('추천', 18),
#  ('김포', 17),
#  ('무료', 17),
#  ('타고', 16),
#  ('요즘', 14),
#  ('반납', 14),
#  ('캐스퍼', 14),
#  ('혹시', 13),
#  ('비용', 13),
#  ('어플', 13),
#  ('때문', 13),
#  ('정말', 13),
#  ('제품', 13),
#  ('시트', 13),
#  ('연습', 13),
#  ('장거리', 12),
#  ('가입', 12),
#  ('광고', 12),
#  ('센터', 12),
#  ('면허증', 12)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(font_path='malgun', width=800, height=800, scale=2.0, max_font_size=250, background_color="white")
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('Socar.png')

# %%
from konlpy.tag import Okt


okt = Okt()
morphs = okt.morphs(result) # 명사만 추출

words = [n for n in morphs if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
c.most_common(50)
# Out:
# [('..', 101),
#  ('ㅎㅎ', 76),
#  ('ll', 70),
#  ('감사합니다', 65),
#  ('...', 64),
#  ('으로', 61),
#  ('이용', 59),
#  ('ㅠㅠ', 59),
#  ('그린', 52),
#  ('에서', 51),
#  ('운전', 49),
#  ('!!', 44),
#  ('ㅋㅋㅋ', 40),
#  ('해서', 38),
#  ('차량', 36),
#  ('경기', 36),
#  ('렌트', 34),
#  ('생각', 34),
#  ('하고', 34),
#  ('터보', 34),
#  ('^^', 31),
#  ('같아요', 30),
#  ('시간', 30),
#  ('많이', 30),
#  ('보험', 30),
#  ('~~', 29),
#  ('입니다', 28),
#  ('주행', 27),
#  ('\n\n', 27),
#  ('정도', 26),
#  ('요금', 26),
#  ('서울', 25),
#  ('좋은', 25),
#  ('사용', 25),
#  ('ㅋㅋ', 25),
#  ('합니다', 24),
#  ('거리', 23),
#  ('하면', 23),
#  ('가격', 23),
#  ('사고', 23),
#  ('보다', 22),
#  ('렌트카', 22),
#  ('그냥', 21),
#  ('정보', 21),
#  ('진짜', 21),
#  ('문제', 21),
#  ('옵션', 21),
#  ('타이어', 21),
#  ('쿠폰', 20),
#  ('너무', 20)]

# %%
# Verb 추출

# %%
okt = Okt()
verb = okt.pos(result, norm=True, stem=True) # 모든 형태소 추출
words = [x for x, y in verb if y in ['Verb']] # 추출된 값 중 동사만 추출

c = Counter(words)
 
#Okt = Text(myList_filter, name="Okt")
c.most_common(50)
# Out:
# [('하다', 453),
#  ('쏘다', 184),
#  ('되다', 108),
#  ('보다', 95),
#  ('감사하다', 81),
#  ('빌리다', 43),
#  ('타다', 42),
#  ('해보다', 40),
#  ('자다', 38),
#  ('않다', 34),
#  ('크다', 32),
#  ('모르다', 29),
#  ('알다', 28),
#  ('나오다', 26),
#  ('가다', 26),
#  ('써다', 25),
#  ('나다', 21),
#  ('싸다', 20),
#  ('해주다', 20),
#  ('오다', 19),
#  ('돼다', 18),
#  ('들다', 18),
#  ('사다', 16),
#  ('드리다', 16),
#  ('싶다', 15),
#  ('이다', 15),
#  ('되어다', 14),
#  ('받다', 14),
#  ('쓰다', 13),
#  ('늘다', 12),
#  ('부르다', 12),
#  ('찾다', 12),
#  ('넣다', 11),
#  ('쓸다', 11),
#  ('넘다', 11),
#  ('차다', 10),
#  ('내다', 9),
#  ('갈다', 9),
#  ('해봤다', 9),
#  ('보이다', 9),
#  ('따르다', 9),
#  ('주다', 9),
#  ('들어가다', 9),
#  ('두다', 8),
#  ('다니다', 8),
#  ('밟다', 8),
#  ('잡다', 8),
#  ('맞다', 8),
#  ('올리다', 8),
#  ('느끼다', 8)]

# %%
okt = Okt()
adjective = okt.pos(result, norm=True, stem=True) # 모든 형태소 추출
words = [x for x, y in adjective if y in ['Adjective']] # 추출된 값 중 동사만 추출

c = Counter(words)
 
#Okt = Text(myList_filter, name="Okt")
c.most_common(50)
# Out:
# [('있다', 131),
#  ('같다', 86),
#  ('없다', 81),
#  ('좋다', 79),
#  ('아니다', 51),
#  ('그렇다', 46),
#  ('많다', 36),
#  ('이다', 29),
#  ('안되다', 25),
#  ('편하다', 20),
#  ('비싸다', 20),
#  ('괜찮다', 15),
#  ('가능하다', 15),
#  ('어떻다', 14),
#  ('저렴하다', 13),
#  ('차갑다', 12),
#  ('비슷하다', 11),
#  ('다르다', 11),
#  ('불편하다', 10),
#  ('작다', 9),
#  ('궁금하다', 8),
#  ('야하다', 8),
#  ('밉다', 7),
#  ('필요하다', 7),
#  ('나쁘다', 6),
#  ('원하다', 5),
#  ('짧다', 5),
#  ('덥다', 5),
#  ('확실하다', 5),
#  ('상관없다', 4),
#  ('가깝다', 4),
#  ('힘들다', 4),
#  ('빠르다', 4),
#  ('똑같다', 4),
#  ('아쉽다', 4),
#  ('즐겁다', 3),
#  ('솔직하다', 3),
#  ('심하다', 3),
#  ('위험하다', 3),
#  ('간단하다', 3),
#  ('당하다', 3),
#  ('애매하다', 3),
#  ('계시다', 3),
#  ('착하다', 3),
#  ('악세다', 3),
#  ('조용하다', 3),
#  ('불안하다', 2),
#  ('편안하다', 2),
#  ('재밌다', 2),
#  ('부족하다', 2)]

# %% [markdown]
# ## 형태소 분석

# %% [markdown]
# ### 한나눔(Hannanum)

# %%
from konlpy.tag import Hannanum
from collections import Counter
hannanum = Hannanum()

nouns = hannanum.nouns(result)
words = [n for n in nouns if len(n) > 1]
stop_words = ['ㅋㅋㅋ','ㅎㅎ','ㅠㅠ','ㅋㅋ','ㅎㅎㅎ','ㅋㅋㅋㅋㅋ','이용','운전','생각','진짜','근데']
result = [w for w in words if not w in stop_words]



c = Counter(result)
 
#Okt = Text(myList_filter, name="Okt")
c.most_common(50)
# Out:
# [('쏘카', 139),
#  ('감사', 59),
#  ('그린카', 48),
#  ('가격', 19),
#  ('터보', 19),
#  ('차량', 17),
#  ('사용', 17),
#  ('시간', 16),
#  ('정보', 16),
#  ('렌트카', 15),
#  ('보험', 15),
#  ('옵션', 15),
#  ('렌트', 14),
#  ('문제', 14),
#  ('쿠폰', 12),
#  ('한번', 12),
#  ('정도', 11),
#  ('장거리', 11),
#  ('운행', 11),
#  ('요금', 10),
#  ('반납', 10),
#  ('캐스퍼', 10),
#  ('제품', 10),
#  ('가솔린', 10),
#  ('무료', 10),
#  ('시승', 10),
#  ('시승센터', 9),
#  ('말씀', 9),
#  ('다행', 9),
#  ('주행거리', 8),
#  ('비용', 8),
#  ('가입', 8),
#  ('어디', 8),
#  ('필요', 8),
#  ('5시간', 8),
#  ('시트', 8),
#  ('연습', 8),
#  ('해결', 8),
#  ('광고', 8),
#  ('어플', 7),
#  ('예전', 7),
#  ('경우', 7),
#  ('때문', 7),
#  ('경차', 7),
#  ('택시', 7),
#  ('자빠님', 7),
#  ('기본', 6),
#  ('가능', 6),
#  ('ㅋㅋㅋㅋ', 6),
#  ('자차', 6)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


wc = WordCloud(font_path='malgun', width=800, height=800, scale=2.0, max_font_size=250, background_color="white")
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
import pandas as pd

review = pd.read_csv("C:/Users/katenam/Socar_Review_Final.csv")
review
# Out:
#                                                Comments
# 0     저는 쏘카 자주 이용해요 빌리기 편해서 ㅎㅎ 쏘카는 거리당 계산이고 주유는 차 안에...
# 1                하루종일 드라이브코스로 돌아다니는데 혹시 가격은 어느정도 나오나요??
# 2             차종 상관없이 100키로 타면 기본 2만원 정도 나오도록 세팅이 되어있어요
# 3     이건 거리당 요금 입니다. 대여료는 잘하면 쿠폰같은걸 써서 50퍼센트 이상 할인도 ...
# 4     저도 6월초에 여수가는데 ktx역에서 내려서 쏘카 이용하려구요~비용은 쿠폰 이것저것...
# ...                                                 ...
# 2920                                   보험료 만원좀 넘게 나오네요~
# 2921  얼리버드 예약으로 카쉐어링 당첨 톡이 왔는데, MMS는 오지안네요, 문자가 와야 시...
# 2922                                  쏘카가 자전거까지 진출했네요 ㅎ
# 2923                                             그러게..ㅎ
# 2924                                         18개 도시 6천대
#
# [2925 rows x 1 columns]
